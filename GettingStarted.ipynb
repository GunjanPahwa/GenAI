# %% [markdown]
# ####Getting Started with Langchain and OpenAI
#
# Here we will:
# 1. Get setup with LangChain,LangServe and LangSmith
# 2. Use the most basic and common components of LangChain: prompt templates, models and output parser.
# 3. Build a simple application with LangChain
# 4. Trace you application with LangSmith
# 5. Serve your application with LangServe
